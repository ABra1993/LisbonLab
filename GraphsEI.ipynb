# %% [markdown]
# # Auditory cortex

# %%
import numpy as np
import pylab as pl
import matplotlib.mlab as mlab
import math
from scipy.stats import skewnorm

# %%
def sigmoid(x):
    return (1 / (1 + np.exp(-x)))

# %%
x1 = [0.5, 3.5, 0.5]
y1 = [1, 4, 1]

x2 = [0.7, 1.7, 0.7]
y2 = [1, 2, 3]

x3 = [0.7, 1.7, 2.7]
y3 = [1, 2, 5]

x4 = [1.1, 3.1, 5.1]
y4 = [1, 3, 5]

x5 = [0.5, 3.5, 0.5]
y5 = [1.5, 3, 1.5]

x6 = [0.5, 3.5, 0.5]
x6_time = [1, 2.8, 3]
y6 = [0.5, 3.5, 0.5]
y6_time = [1.1, 2.1, 3.1]

# preferred excitation
mu1 = 0
variance1 = 1
sigma1 = math.sqrt(variance1)
vx1 = np.linspace(mu1 - 3 * sigma1, mu1 + 3*sigma1, 100)
vy1 = mlab.normpdf(vx1, mu1, sigma1)

# preferred inhibition
mu2 = 0.3
variance2 = 1
sigma2 = math.sqrt(variance2)
vx2 = np.linspace(mu2 - 3*sigma2, mu2+3*sigma2, 100)
vy2 = mlab.normpdf(vx2, mu2, sigma2)

# preferred stimulus
mu3 = 0.2
variance3 = 1
sigma3 = math.sqrt(variance3)
vx3 = np.linspace(mu3 - 3*sigma3, mu3+3*sigma3, 100)
vy3 = mlab.normpdf(vx3, mu3, sigma3)

# binominal inhibition
mu4 = -4
variance4 = 1
sigma4 = math.sqrt(variance4)
vx4 = np.linspace(mu4 - 3*sigma4, mu4+3*sigma4, 100)
vy4 = mlab.normpdf(vx4, mu4, sigma4)

mu5 = 4
variance5 = 1
sigma5 = math.sqrt(variance5)
vx5 = np.linspace(mu5 - 3*sigma5, mu5+3*sigma5, 100)
vy5 = mlab.normpdf(vx5, mu5, sigma5)

# binominal excitation
mu6 = -4.2
variance6 = 1
sigma6 = math.sqrt(variance6)
vx6 = np.linspace(mu6 - 3*sigma6, mu6+3*sigma6, 100)
vy6 = mlab.normpdf(vx6, mu6, sigma6)

mu7 = 4.2
variance7 = 1
sigma7 = math.sqrt(variance7)
vx7 = np.linspace(mu7 - 3*sigma7, mu7+3*sigma7, 100)
vy7 = mlab.normpdf(vx7, mu7, sigma7)

# broad inhibition
mu8 = 0
variance8 = 4
sigma8 = math.sqrt(variance8)
vx8 = np.linspace(mu8 - 3*sigma8, mu8+3*sigma8, 100)
vy8 = mlab.normpdf(vx8, mu8, sigma8)

mu8E = 0.2
variance8E = 4
sigma8E = math.sqrt(variance8E)
vx8E = np.linspace(mu8E - 3*sigma8E, mu8E+3*sigma8E, 100)
vy8E = mlab.normpdf(vx8E, mu8E, sigma8E)

# skewed excitation and corresponding inhibition
a=-6
mean, var, skew, kurt = skewnorm.stats(a, moments='mvsk')
vx9 = np.linspace(skewnorm.ppf(0.01, a),skewnorm.ppf(0.99, a), 100)

# skewed inhibition
mu10 = -1.8
variance10 = 0.3
sigma10 = math.sqrt(variance10)
vx10 = np.linspace(mu10 - 3*sigma10, mu10+3*sigma10, 100)
vy10 = mlab.normpdf(vx10, mu10, sigma10)

# Visual
mu11 = 0
variance11 = 1
sigma11 = math.sqrt(variance11)
vx11 = np.linspace(mu11 - 3*sigma11, mu11+3*sigma11, 100)
vy11 = mlab.normpdf(vx11, mu11, sigma11)

mu12 = 4
variance12 = 1
sigma12 = math.sqrt(variance12)
vx12 = np.linspace(mu12 - 3*sigma12, mu12+3*sigma12, 100)
vy12 = mlab.normpdf(vx12, mu12, sigma12)
# Out:
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:47: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:60: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:66: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:73: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# ...

# %%
ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 1
column = 3

pl.subplots(row, column, figsize=(24,4))

pl.subplot(row, column, 1)
pl.plot(vx1,vy1, color='red', label='Excitation')
pl.plot(vx8,vy8,color='blue', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.plot(vx1,vy1, color='blue', label='Excitation')
pl.plot(vx2,vy2,color='red', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xlim(4, -4)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 3)
pl.plot(vx10, vy10,'blue')
pl.plot(vx9, skewnorm.pdf(vx9, a),color='red')
pl.ylim(ylim_bottom, 1)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
# prepare the plot, associate the color r(ed) or b(lue) and the label 

ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 1
column = 5

pl.subplots(row, column, figsize=(24,4))

pl.subplot(row, column, 1)
pl.plot(x4, color='red')
pl.plot(y4,color='blue')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.plot(vx1, vy1, color='red')
pl.plot(vx2, vy2, color='blue')
pl.ylim(0,0.5)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 3)
x = pl.linspace(-5,5,1000)
pl.plot(vx1, vy1, color='red')
#pl.plot(x, sigmoid(x), 'blue')
pl.ylim(ylim_bottom,1)
pl.xlim(-5, 5)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 4)
pl.plot(x3, color='red')
#pl.plot(y3,color='blue')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 5)
pl.plot(x4, color='red', label='Excitation')
pl.plot(y4,color='blue', label='Inhibition')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
x = pl.linspace(-5,5,1000)
#pl.plot(vx1, vy1, color='red')
pl.plot(x, sigmoid(x), 'blue')
pl.ylim(ylim_bottom,1)
pl.xlim(-5, 5)
pl.xticks([])
pl.yticks([])
pl.axis('off')
# Out:
# (-5.0, 5.0, 0.0, 1.0)

# %%
ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 5
column = 4

pl.subplots(row, column, figsize=(19,15))

pl.subplot(row, column, 1)
pl.plot(vx1,vy1, color='blue', label='Excitation')
pl.plot(vx8,vy8,color='red', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.axis('off')
pl.subplot(row, column, 3)
pl.axis('off')
pl.subplot(row, column, 4)
pl.axis('off')

pl.subplot(row, column, 5)
pl.plot(vx1,vy1, color='blue', label='Excitation')
pl.plot(vx2,vy2,color='red', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 6)
pl.axis('off')
pl.subplot(row, column, 7)
pl.axis('off')
pl.subplot(row, column, 8)
pl.axis('off')

pl.subplot(row, column, 9)
pl.plot(vx10, vy10,'r')
pl.plot(vx9, skewnorm.pdf(vx9, a),'blue')
pl.ylim(ylim_bottom, 1)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 10)
pl.axis('off')
pl.subplot(row, column, 11)
pl.axis('off')
pl.subplot(row, column, 12)
pl.axis('off')

pl.subplot(row, column, 13)
pl.plot(x4, color='blue')
pl.plot(y4,color='red')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 14)
pl.axis('off')
pl.subplot(row, column, 15)
pl.axis('off')
pl.subplot(row, column, 16)
pl.axis('off')

pl.subplot(row, column, 17)
pl.plot(x1, color='blue')
pl.plot(y1,color='red')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 18)
pl.plot(x2, color='blue')
pl.plot(y2,color='red')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 19)
pl.plot(x3, color='blue')
pl.plot(y3,color='red')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 20)
pl.plot(x4, color='blue', label='Excitation')
pl.plot(y4,color='red', label='Inhibition')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])
pl.legend(bbox_to_anchor=(-2.93, -0.1), prop={'size': 16})

# %%
pl.plot(vx1,vy1, color='red', label='Excitation')
pl.plot(vx2,vy2,color='blue', label='Inhibition')
pl.ylim(0,0.5)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 1
column = 3

pl.subplots(row, column, figsize=(19,4))

pl.subplot(row, column, 1)
pl.plot(vx1,vy1, color='black', label='Excitation')
pl.plot(vx2,vy2,color='grey', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xlim(-7, 7)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.plot(vx1, vy1,'blue')
pl.plot(vx8, vy8,'red')
pl.ylim(ylim_bottom, ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 3)
pl.plot(vx8, vy8,color='blue', label='Inhibition')
pl.plot(vx8E, vy8E,color='darkred', label = 'Excitation')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 2
column = 4

pl.subplots(row, column, figsize=(15,7))

pl.subplot(row, column, 1)
pl.plot(x4, color='blue')
pl.plot(y4,color='red')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.axis('off')
pl.subplot(row, column, 3)
pl.axis('off')
pl.subplot(row, column, 4)
pl.axis('off')

pl.subplot(row, column, 5)
pl.plot(x1, color='blue')
pl.plot(y1,color='red')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 6)
pl.plot(x2, color='blue')
pl.plot(y2,color='red')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 7)
pl.plot(x3, color='blue')
pl.plot(y3,color='red')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 8)
pl.plot(x4, color='blue')
pl.plot(y4,color='red')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 1
column = 2

pl.subplots(row, column, figsize=(14,4))

pl.subplot(row, column, 1)
pl.plot(vx1,vy1, color='darkred', label='Excitation')
pl.plot(vx8,vy8,color='blue', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])
pl.axis('off')

# pl.subplot(row, column, 2)
# pl.plot(vx1,vy1, color='black', label='Excitation')
# pl.plot(vx2,vy2,color='grey', label='Inhibition')
# pl.ylim(ylim_bottom,ylim_top)
# pl.xticks([])
# pl.yticks([])

pl.subplot(row, column, 2)
pl.plot(vx10, vy10,color='darkred')
pl.plot(vx9, skewnorm.pdf(vx9, a),color='blue')
pl.ylim(ylim_bottom, 1)
pl.xticks([])
pl.yticks([])
pl.axis('off')
# Out:
# (-3.6239633121092374, 0.3535407589530245, 0.0, 1.0)

# %%
## DISCUSSION
pl.plot(vx1,vy1, color='black', label='Excitation')
pl.plot(vx2,vy2,color='grey', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
row = 3
column = 5
pl.subplot(row, column, 1)
pl.plot(vx1,vy1, color='blue', label='Excitation')
pl.plot(vx8,vy8,color='red', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.axis('off')

pl.subplot(row, column, 3)
pl.axis('off')

pl.subplot(row, column, 4)
pl.axis('off')

pl.subplot(row, column, 5)
pl.axis('off')

pl.subplot(row, column, 6)
pl.plot(vx1,vy1, color='blue', label='Excitation')
pl.plot(vx2,vy2,color='red', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 7)
pl.plot(vx1,vy1, color='blue', label='Excitation')
pl.plot(vx2,vy2,color='red', label='Inhibition')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 8)
pl.plot(x2, color='blue')
pl.plot(y2,color='red')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 9)
pl.plot(x3, color='blue')
pl.plot(y3,color='red')
pl.ylim(ylim_bottom,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 10)
pl.plot(x4, color='blue')
pl.plot(y4,color='red')
pl.ylim(0,6)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 11)
pl.plot(vx10, vy10,'r',label='Inhibition')
pl.plot(vx9, skewnorm.pdf(vx9, a),'blue',label='Excitation')
pl.ylim(ylim_bottom, 1)
pl.xticks([])
pl.yticks([])
pl.legend(bbox_to_anchor=(0.78, -0.1))

pl.subplot(row, column, 12)
pl.axis('off')

pl.subplot(row, column, 13)
pl.axis('off')

pl.subplot(row, column, 14)
pl.axis('off')

pl.subplot(row, column, 15)
pl.axis('off')
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %% [markdown]
# # Visual cortex

# %%
# preferred excitation
mu1 = 0
variance1 = 1
sigma1 = math.sqrt(variance1)
vx1 = np.linspace(mu1 - 3 * sigma1, mu1 + 3*sigma1, 100)
vy1 = mlab.normpdf(vx1, mu1, sigma1)

# preferred inhibition
mu2 = 0.2
variance2 = 1
sigma2 = math.sqrt(variance2)
vx2 = np.linspace(mu2 - 3*sigma2, mu2+3*sigma2, 100)
vy2 = mlab.normpdf(vx2, mu2, sigma2)

# preferred stimulus
mu3 = 0.4
variance3 = 1
sigma3 = math.sqrt(variance3)
vx3 = np.linspace(mu3 - 3*sigma3, mu3+3*sigma3, 100)
vy3 = mlab.normpdf(vx3, mu3, sigma3)

# binominal inhibition
mu4 = -4
variance4 = 1
sigma4 = math.sqrt(variance4)
vx4 = np.linspace(mu4 - 3*sigma4, mu4+3*sigma4, 100)
vy4 = mlab.normpdf(vx4, mu4, sigma4)

mu5 = 4
variance5 = 1
sigma5 = math.sqrt(variance5)
vx5 = np.linspace(mu5 - 3*sigma5, mu5+3*sigma5, 100)
vy5 = mlab.normpdf(vx5, mu5, sigma5)

# binominal excitation
mu6 = -4.2
variance6 = 1
sigma6 = math.sqrt(variance6)
vx6 = np.linspace(mu6 - 3*sigma6, mu6+3*sigma6, 100)
vy6 = mlab.normpdf(vx6, mu6, sigma6)

mu7 = 4.2
variance7 = 1
sigma7 = math.sqrt(variance7)
vx7 = np.linspace(mu7 - 3*sigma7, mu7+3*sigma7, 100)
vy7 = mlab.normpdf(vx7, mu7, sigma7)

# seperated excitation and inhibition
mu8 = 0
variance8 = 1
sigma8 = math.sqrt(variance8)
vx8 = np.linspace(mu8 - 3*sigma8, mu8+3*sigma8, 100)
vy8 = mlab.normpdf(vx8, mu8, sigma8)

mu9 = 4
variance9 = 1
sigma9 = math.sqrt(variance9)
vx9 = np.linspace(mu9 - 3*sigma9, mu9+3*sigma9, 100)
vy9 = mlab.normpdf(vx9, mu9, sigma9)
# Out:
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:6: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
#
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:13: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
#   del sys.path[0]
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:33: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:40: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:46: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# C:\Users\amber\Anaconda3\lib\site-packages\ipykernel_launcher.py:53: MatplotlibDeprecationWarning: scipy.stats.norm.pdf
# ...

# %%
ylim_bottom = 0
ylim_top = 0.5
xlim_bottom = -10
xlim_top = 10
row = 1
column = 5

pl.subplots(row, column, figsize=(26,4))

pl.subplot(row, column, 1)
pl.plot(vx1,vy1, color='red', label='Excitation')
pl.plot(vx2,vy2,color='blue', label='Inhibition')
pl.plot(vx3,vy3,'k--',label='Preferred orientation')
pl.ylim(ylim_bottom,ylim_top)
pl.xlim(xlim_bottom,xlim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.plot(vx1,vy1, color='red', label='Excitation')
pl.plot(vx2,vy2,color='blue', label='Inhibition')
pl.plot(vx3,vy3,'k--',label='Preferred orientation')
pl.ylim(ylim_bottom,ylim_top)
pl.xlim(xlim_bottom,xlim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 3)
pl.plot(vx1, vy1, color='red', label='Excitation')
pl.plot(vx4, vy4, color='blue', label='Inhibition')
pl.plot(vx5, vy5, color='blue')
pl.plot(vx3, vy3,'k--',label='Preferred orientation')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 4)
pl.plot(vx4, vy4,color='blue', label='Inhibition')
pl.plot(vx5, vy5,color='blue')
pl.plot(vx6, vy6,color='red', label='Excitation')
pl.plot(vx7, vy7,color='red')
pl.plot(vx3, vy3,'k--',label='Preferred orientation')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 5)
pl.plot(vx8, vy8,color='blue', label='Inhibition')
pl.plot(vx9, vy9,color='red', label = 'Excitation')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
pl.plot(vx8, vy8,color='black', label='Inhibition')
pl.plot(vx9, vy9,color='grey', label = 'Excitation')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)

# %%
ylim_bottom = 0
ylim_top = 0.45
xlim_bottom = -10
xlim_top = 10
row = 1
column = 3

pl.subplots(row, column, figsize=(18,4))

pl.subplot(row, column, 1)
pl.plot(vx1, vy1, color='red', label='Dark')
pl.plot(vx4, vy4, color='red', alpha = 0.4, label='Bright')
pl.plot(vx5, vy5, color='red', alpha = 0.4)
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 2)
pl.plot(vx1,vy1, color='blue',  alpha = 0.4, label='Dark')
pl.plot(vx4, vy4, color='blue', label='Bright')
pl.plot(vx5, vy5, color='blue')
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])

pl.subplot(row, column, 3)
pl.plot(vx1, vy1, color='blue', alpha= 0.4)
pl.plot(vx2, vy2, color='blue',)
pl.ylim(ylim_bottom,ylim_top)
pl.xticks([])
pl.yticks([])
# Out:
# ([], <a list of 0 Text yticklabel objects>)
